# %% [markdown]
# # <center>Rocket Lab Dados - 2025.2</center>
# # <center> Introdução à Pyspark</center>
# ___
# Todo o conteúdo que você terá acesso ao longo desse período é confidencial, não sendo possível compartilhar ou comercializar os links ou os materiais recebidos que sejam de propriedade do Programa Rocket Lab da V(dev)
#
# Dessa forma, ao participar do curso você está aceitando os termos de confidencialidade e não-comercialização dos conteúdos que serão recebidos.
# ___
#
# # <center> Objetivos de aprendizado </center>
# - Familiarizar-se com as funcionalidades básicas do PySpark
# - Ser capaz de carregar dados em um DataFrame
# - Ser capaz de realizar manipulações básicas de dados
# ___

# %% [markdown]
# ### 1. Juntando DataFrames
#
# É muito comum ter a necessidade de juntar *DataFrames* diferentes. Se você já utilizou SQL ou qualquer outro banco de dados relacional, deve conhecer isso como *join*. O Pandas também tem a mesma função utilizando o método *.merge()*. Antes do exemplo, vamos aprender/relembrar os tipos de *joins* mais comuns:<br>
# ![Joining Methods](https://i.imgur.com/HaSBT91.jpg) <br>
# Agora, vamos carregar um DataFrame mais simples para testar os tipos de *merge*.

# %% [markdown]
# Para os exemplos abaixo iremos utilizar o Datafram: **metal_bands**, contendo as informações sobre bandas de metal do mundo todo, suas origens e estilos musicais.
#
# Principais colunas:
# - Band — nome da banda
# - Origin — país de origem
# - Fans — número aproximado de fãs
# - Formed — ano de formação
# - Split — ano de separação ('-', se ainda ativa)
# - Style — subgênero do metal (ex: Heavy Metal, Black Metal, Thrash Metal)

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

#Criar sessão spark
spark = SparkSession.builder.appName("AtividadePraticaSpark").getOrCreate()

# Execute esta célula para carregar o dataframe metal_bands com dados de bandas de metal
metal_bands = spark.table("workspace.default.metal_bands")

metal_bands.printSchema()
display(metal_bands.limit(5))
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- band_name: string (nullable = true)
#  |-- fans: long (nullable = true)
#  |-- formed: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- split: string (nullable = true)
#  |-- style: string (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>band_name</th><th>fans</th><th>formed</th><th>origin</th><th>split</th><th>style</th></tr></thead><tbody><tr><td>0</td><td>Iron Maiden</td><td>4195</td><td>1975</td><td>United Kingdom</td><td>-</td><td>New wave of british heavy,Heavy</td></tr><tr><td>1</td><td>Opeth</td><td>4147</td><td>1990</td><td>Sweden</td><td>1990</td><td>Extreme progressive,Progressive rock,Progressive</td></tr><tr><td>2</td><td>Metallica</td><td>3712</td><td>1981</td><td>USA</td><td>-</td><td>Heavy,Bay area thrash</td></tr><tr><td>3</td><td>Megadeth</td><td>3105</td><td>1983</td><td>USA</td><td>1983</td><td>Thrash,Heavy,Hard rock</td></tr><tr><td>4</td><td>Amon Amarth</td><td>3054</td><td>1988</td><td>Sweden</td><td>-</td><td>Melodic death</td></tr></tbody></table></div>

# %% [markdown]
# Vamos separar alguns dataframes a partir de *metal_bands* para testar os merges. Observe a célula abaixo.

# %%
# ano de formação e país das bandas
bands_origin = metal_bands.select('id','band_name','formed','origin')

# estilo das bandas
bands_style = metal_bands.select('id','band_name','style') # estilo das bandas

# bandas que se separaram
bands_split = (metal_bands
               .select('id','band_name','split')
               .where(F.column('split') != "-")
               )

# bandas com mais de 4000 fans
bands_4000_fans = (metal_bands
                   .select('id','band_name','fans')
                   .where(F.column('fans') > 4000)
                   )

# bandas formadas nos EUA
bands_USA = (metal_bands
             .select('id','band_name','formed','origin')
             .where(F.column('origin') == "USA")
             )

# bandas formadas na Suécia
bands_Sweden = (metal_bands
                .select('id','band_name','formed','origin')
                .where(F.column('origin') == 'Sweden')
                )

# %% [markdown]
# Vamos criar um DataFrame a partir de ```bands_origin``` e ```bands_split```, utilizando *merge*.

# %%
origin_split = (bands_origin # o DataFrame da esquerda
                .join(bands_split, # o DataFrame da direita
                      on=['id', 'band_name'], # baseado em quais valores em comum (chave)
                      how='inner' # o tipo de join que queremos fazer
                      )
                )
display(origin_split.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>band_name</th><th>formed</th><th>origin</th><th>split</th></tr></thead><tbody><tr><td>1</td><td>Opeth</td><td>1990</td><td>Sweden</td><td>1990</td></tr><tr><td>3</td><td>Megadeth</td><td>1983</td><td>USA</td><td>1983</td></tr><tr><td>5</td><td>Slayer</td><td>1981</td><td>USA</td><td>1981</td></tr><tr><td>6</td><td>Death</td><td>1983</td><td>USA</td><td>2001</td></tr><tr><td>7</td><td>Dream Theater</td><td>1985</td><td>USA</td><td>1985</td></tr></tbody></table></div>

# %% [markdown]
# Ótimo! Conseguimos fazer o *Join* de dois *DataFrames*. Observe que utilizamos o argumento ```how='inner'```. Lembre-se que *inner*, *left*, *right* e *outer* terão resultados diferentes, observe os merges abaixo e a explicação ao final.

# %%
left_origin_split = (bands_origin
                     .join(bands_split,
                           on= ['id', 'band_name'],
                           how="left"
                           )
                     )
display(left_origin_split.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>band_name</th><th>formed</th><th>origin</th><th>split</th></tr></thead><tbody><tr><td>0</td><td>Iron Maiden</td><td>1975</td><td>United Kingdom</td><td>null</td></tr><tr><td>1</td><td>Opeth</td><td>1990</td><td>Sweden</td><td>1990</td></tr><tr><td>2</td><td>Metallica</td><td>1981</td><td>USA</td><td>null</td></tr><tr><td>3</td><td>Megadeth</td><td>1983</td><td>USA</td><td>1983</td></tr><tr><td>4</td><td>Amon Amarth</td><td>1988</td><td>Sweden</td><td>null</td></tr></tbody></table></div>

# %%
right_origin_split = (bands_origin
                     .join(bands_split,
                           on= ['id', 'band_name'],
                           how="right"
                           )
                     )
display(right_origin_split.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>band_name</th><th>formed</th><th>origin</th><th>split</th></tr></thead><tbody><tr><td>1</td><td>Opeth</td><td>1990</td><td>Sweden</td><td>1990</td></tr><tr><td>3</td><td>Megadeth</td><td>1983</td><td>USA</td><td>1983</td></tr><tr><td>5</td><td>Slayer</td><td>1981</td><td>USA</td><td>1981</td></tr><tr><td>6</td><td>Death</td><td>1983</td><td>USA</td><td>2001</td></tr><tr><td>7</td><td>Dream Theater</td><td>1985</td><td>USA</td><td>1985</td></tr></tbody></table></div>

# %%
print('Numero de linhas do DataFrame bands_4000_fans:', bands_4000_fans.count())
print('Numero de linhas do DataFrame bands_USA:', bands_USA.count())
print('----------------------------------------------')

outer_origin_split = (bands_4000_fans
                     .join(bands_USA,
                           on= ['id', 'band_name'],
                           how="outer"
                           )
                     )

print('Numero de linhas do DataFrame após Outer entre bands_4000_fans & bands_USA:', outer_origin_split.count())
display(outer_origin_split.limit(5))
# Out:
# Numero de linhas do DataFrame bands_4000_fans: 4
# Numero de linhas do DataFrame bands_USA: 1139
# ----------------------------------------------
# Numero de linhas do DataFrame após Outer entre bands_4000_fans & bands_USA: 1143
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>band_name</th><th>fans</th><th>formed</th><th>origin</th></tr></thead><tbody><tr><td>763</td><td>The Absence</td><td>null</td><td>2002</td><td>USA</td></tr><tr><td>3417</td><td>Hail!Hornet</td><td>null</td><td>2006</td><td>USA</td></tr><tr><td>103</td><td>Nevermore</td><td>null</td><td>1991</td><td>USA</td></tr><tr><td>3933</td><td>Kowloon Walled City</td><td>null</td><td>2007</td><td>USA</td></tr><tr><td>1812</td><td>Black Fast</td><td>null</td><td>2010</td><td>USA</td></tr></tbody></table></div>

# %% [markdown]
# Como podemos ver, os resultados são de fato bem diferentes.
#
# O *inner* mantém apenas os dados das bandas encontradas nos dois dataframes (onde há correspondência de *id*), dessa forma, a posição do dataframe não faz diferença.
#
# No *left*, mantemos os dados do dataframe à esquerda, e trazemos os dados do dataframe à direita no qual encontrou-se a chave (neste exemplo, o *id* da banda).
#
# Por outro lado, no *right* ocorre o contrário, mantemos os dados do dataframe à direita e, quando há correspondência da chave, trazemos os dados do dataframe à esquerda. Note que o número de entradas (*entries*) é diferente do caso com o *left*. Isso ocorre porque no *left* mantemos os dados de formação das bandas (ou seja, o dataframe contém todas as bandas do .csv), enquanto no *right*, mantemos apenas os dados de bandas que se separaram (e existem muitas bandas que ainda continuam juntas).
#
# Por fim, no *outer* utilizamos dois dataframes diferentes dos anteriores para facilitar o entendimento. Observe pelos prints que existem apenas 4 bandas com mais de 4000 fans e 1139 bandas formadas nos EUA. Quando fazemos o *join* com *outer*, observe que o total de linhas passa a ser 1143. O que acontece é que esse tipo de join mantém os dados de ambos os dataframes, independente se houve correspondência de chave ou não.
#
# Podemos também querer apenas concatenar dois *DataDrames*, isto é, juntá-los colocando um abaixo do outro. Para isso, utilizamos o método *.union()*:

# %%
# concatenando bandas formadas nos EUA e bandas formadas na Suécia
USA_Sweden = bands_USA.union(bands_Sweden)

print('Numero de linhas do DataFrame bands_USA:', bands_USA.count())
print('Numero de linhas do DataFrame bands_Sweden:', bands_Sweden.count())
print('Numero de linhas do DataFrame após union entre bands_USA & bands_Sweden:', USA_Sweden.count())
display(USA_Sweden.limit(5))
# Out:
# Numero de linhas do DataFrame bands_USA: 1139
# Numero de linhas do DataFrame bands_Sweden: 476
# Numero de linhas do DataFrame após union entre bands_USA & bands_Sweden: 1615
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>band_name</th><th>formed</th><th>origin</th></tr></thead><tbody><tr><td>2</td><td>Metallica</td><td>1981</td><td>USA</td></tr><tr><td>3</td><td>Megadeth</td><td>1983</td><td>USA</td></tr><tr><td>5</td><td>Slayer</td><td>1981</td><td>USA</td></tr><tr><td>6</td><td>Death</td><td>1983</td><td>USA</td></tr><tr><td>7</td><td>Dream Theater</td><td>1985</td><td>USA</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercício 1
# O Ultimate Team (FUT) é um modo do jogo FIFA no qual o jogador monta seu próprio time adquirindo atletas virtuais.
# Cada atleta possui atributos que influenciam seu desempenho em campo — como drible, chute, passe, defesa, velocidade e físico.
#
# Principais colunas:
# - `player_id` — identificador único do jogador
# - `player_name` — nome do atleta
# - `nationality` — país de origem
# - `club` — clube atual
# - `overall` — nota geral do jogador
# - `potential` — potencial máximo de evolução
# - `value_eur, wage_eur` — valor de mercado e salário
# - `age, height_cm, weight_kg` — características físicas
# - `pace, shooting, passing, dribbling, defending, physic` — atributos técnicos
#
# _**Preencha os espacos ____ para carregar os dados e realizar as consultas propostas.**_

# %% [markdown]
# ### Exercício 1.1 Faça a leitura do arquivo fut_players (fut_player_data.csv) e retorne as 5 primeiras linhas

# %%
# Faça a leitura do arquivo fut_players 
fut_players = spark.table("workspace.default.fut_players_data")

# Retorne as 5 primeiras linhas do DF
display(fut_players.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>player_id</th><th>player_name</th><th>player_extended_name</th><th>quality</th><th>revision</th><th>origin</th><th>overall</th><th>club</th><th>league</th><th>nationality</th><th>position</th><th>age</th><th>date_of_birth</th><th>height</th><th>weight</th><th>intl_rep</th><th>added_date</th><th>pace</th><th>pace_acceleration</th><th>pace_sprint_speed</th><th>dribbling</th><th>drib_agility</th><th>drib_balance</th><th>drib_reactions</th><th>drib_ball_control</th><th>drib_dribbling</th><th>drib_composure</th><th>shooting</th><th>shoot_positioning</th><th>shoot_finishing</th><th>shoot_shot_power</th><th>shoot_long_shots</th><th>shoot_volleys</th><th>shoot_penalties</th><th>passing</th><th>pass_vision</th><th>pass_crossing</th><th>pass_free_kick</th><th>pass_short</th><th>pass_long</th><th>pass_curve</th><th>defending</th><th>def_interceptions</th><th>def_heading</th><th>def_marking</th><th>def_stand_tackle</th><th>def_slid_tackle</th><th>physicality</th><th>phys_jumping</th><th>phys_stamina</th><th>phys_strength</th><th>phys_aggression</th><th>gk_diving</th><th>gk_reflexes</th><th>gk_handling</th><th>gk_speed</th><th>gk_kicking</th><th>gk_positoning</th><th>pref_foot</th><th>att_workrate</th><th>def_workrate</th><th>weak_foot</th><th>skill_moves</th><th>cb</th><th>rb</th><th>lb</th><th>rwb</th><th>lwb</th><th>cdm</th><th>cm</th><th>rm</th><th>lm</th><th>cam</th><th>cf</th><th>rf</th><th>lf</th><th>rw</th><th>lw</th><th>st</th><th>traits</th><th>specialities</th><th>base_id</th></tr></thead><tbody><tr><td>1</td><td>Pelé</td><td>Arantes Nascimento Edson</td><td>Gold - Rare</td><td>Icon</td><td>Prime</td><td>98</td><td>Icons</td><td>Icons</td><td>Brazil</td><td>CAM</td><td>78</td><td>1940-10-23</td><td>173</td><td>70</td><td>0</td><td>2018-09-19</td><td>95.0</td><td>95</td><td>95</td><td>96.0</td><td>94</td><td>93</td><td>98</td><td>97</td><td>96</td><td>98</td><td>96.0</td><td>97</td><td>98</td><td>94</td><td>94</td><td>95</td><td>93</td><td>93.0</td><td>97</td><td>90</td><td>89</td><td>96</td><td>88</td><td>89</td><td>60.0</td><td>67</td><td>94</td><td>55</td><td>53</td><td>49</td><td>76.0</td><td>88</td><td>86</td><td>76</td><td>59</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Right</td><td>High</td><td>Med</td><td>4</td><td>5</td><td>70.0</td><td>77.0</td><td>77.0</td><td>79.0</td><td>79.0</td><td>77.0</td><td>91.0</td><td>95.0</td><td>95.0</td><td>96.0</td><td>96.0</td><td>96.0</td><td>96.0</td><td>96.0</td><td>96.0</td><td>95.0</td><td>Finesse Shot</td><td>Speedster, Aerial Threat, Dribbler, Play Maker, Distance Shooter, Crosser, FK Specialist, Acrobat, Clinical Finisher, Midfielder, Complete Forward, Poacher</td><td>237067</td></tr><tr><td>2</td><td>Maradona</td><td>Diego Maradona</td><td>Gold - Rare</td><td>Icon</td><td>Prime</td><td>97</td><td>Icons</td><td>Icons</td><td>Argentina</td><td>CAM</td><td>58</td><td>1960-10-30</td><td>165</td><td>70</td><td>0</td><td>2018-09-19</td><td>92.0</td><td>94</td><td>90</td><td>97.0</td><td>91</td><td>98</td><td>94</td><td>97</td><td>98</td><td>95</td><td>93.0</td><td>92</td><td>97</td><td>85</td><td>94</td><td>88</td><td>94</td><td>92.0</td><td>95</td><td>88</td><td>96</td><td>93</td><td>89</td><td>96</td><td>40.0</td><td>44</td><td>67</td><td>27</td><td>42</td><td>37</td><td>76.0</td><td>82</td><td>78</td><td>75</td><td>76</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Left</td><td>High</td><td>Med</td><td>3</td><td>5</td><td>57.0</td><td>66.0</td><td>66.0</td><td>71.0</td><td>71.0</td><td>69.0</td><td>88.0</td><td>93.0</td><td>93.0</td><td>95.0</td><td>94.0</td><td>94.0</td><td>94.0</td><td>94.0</td><td>94.0</td><td>90.0</td><td>Avoids Using Weaker Foot, Finesse Shot, Flair, Takes Finesse Free Kicks</td><td>Speedster, Dribbler, Play Maker, Distance Shooter, Crosser, FK Specialist, Acrobat, ...

# %% [markdown]
# ### Exercício 1.2 - Retorna a nacionalidade dos jogadores "The Bests"
#
# São considerados jogadores The Bests os que possuem os atributos de drible (_dribbling_) e chute (_shooting_) superior a 90.
# Após a geração do DF _The_Best_ realize o join com o df _nationalities_ para obter a nacionalidade dos jogadores.
#
# A sua tabela final deve conter as seguintes informações:
# - `player_id`
# - `player_name`
# - `nationality`
# - `position`
# - `dribbling`
# - `shooting`
# - `overall`

# %%
the_best = (
    fut_players
    .filter((F.col("dribbling") > 90) & (F.col("shooting") > 90))
    )

nationalities = (
    fut_players
    .select('player_id', 'player_name', 'nationality')
    )

the_best_nationality = (the_best
    .join(nationalities,
          on='player_id',
          how = 'left')
    .drop(nationalities.player_name)  # removendo a coluna 'player_name' vinda do df 'nationalities' para n ter duplicatas
    .drop(nationalities.nationality)
)

df_final_1_2 = the_best_nationality.select(
    "player_id", 
    "player_name", 
    "nationality", 
    "position", 
    "dribbling", 
    "shooting", 
    "overall"
)

df_final_1_2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>player_id</th><th>player_name</th><th>nationality</th><th>position</th><th>dribbling</th><th>shooting</th><th>overall</th></tr></thead><tbody><tr><td>1</td><td>Pelé</td><td>Brazil</td><td>CAM</td><td>96.0</td><td>96.0</td><td>98</td></tr><tr><td>2</td><td>Maradona</td><td>Argentina</td><td>CAM</td><td>97.0</td><td>93.0</td><td>97</td></tr><tr><td>3</td><td>Ronaldo</td><td>Brazil</td><td>ST</td><td>95.0</td><td>95.0</td><td>96</td></tr><tr><td>4</td><td>Pelé</td><td>Brazil</td><td>CF</td><td>95.0</td><td>93.0</td><td>95</td></tr><tr><td>5</td><td>Maradona</td><td>Argentina</td><td>CAM</td><td>95.0</td><td>91.0</td><td>95</td></tr><tr><td>7</td><td>Ronaldo</td><td>Brazil</td><td>ST</td><td>93.0</td><td>93.0</td><td>94</td></tr><tr><td>12</td><td>Best</td><td>Northern Ireland</td><td>RW</td><td>94.0</td><td>91.0</td><td>93</td></tr><tr><td>18</td><td>Del Piero</td><td>Italy</td><td>CF</td><td>92.0</td><td>92.0</td><td>92</td></tr><tr><td>30</td><td>Stoichkov</td><td>Bulgaria</td><td>ST</td><td>92.0</td><td>93.0</td><td>92</td></tr><tr><td>74</td><td>Zola</td><td>Italy</td><td>CF</td><td>91.0</td><td>91.0</td><td>90</td></tr><tr><td>340</td><td>Messi</td><td>Argentina</td><td>CF</td><td>97.0</td><td>92.0</td><td>95</td></tr><tr><td>341</td><td>Messi</td><td>Argentina</td><td>CF</td><td>96.0</td><td>91.0</td><td>94</td></tr><tr><td>13088</td><td>Cruyff</td><td>Holland</td><td>CF</td><td>94.0</td><td>92.0</td><td>94</td></tr><tr><td>13090</td><td>Eusébio</td><td>Portugal</td><td>CF</td><td>93.0</td><td>94.0</td><td>93</td></tr><tr><td>13091</td><td>Rivaldo</td><td>Brazil</td><td>LW</td><td>92.0</td><td>91.0</td><td>92</td></tr><tr><td>16950</td><td>Ronaldo</td><td>Portugal</td><td>ST</td><td>91.0</td><td>94.0</td><td>95</td></tr><tr><td>16968</td><td>Ronaldo</td><td>Portugal</td><td>ST</td><td>91.0</td><td>94.0</td><td>95</td></tr><tr><td>17101</td><td>Mandžukic</td><td>Croatia</td><td>ST</td><td>93.0</td><td>93.0</td><td>85</td></tr><tr><td>17106</td><td>Abdulrahman</td><td>United Arab Emirates</td><td>CAM</td><td>93.0</td><td>93.0</td><td>77</td></tr><tr><td>17111</td><td>Çalhanoglu</td><td>Turkey</td><td>LW</td><td>93.0</td><td>93.0</td><td>81</td></tr><tr><td>17223</td><td>Agüero</td><td>Argentina</td><td>ST</td><td>91.0</td><td>92.0</td><td>91</td></tr><tr><td>17387</td><td>Messi</td><td>Argentina</td><td>RW</td><td>97.0</td><td>92.0</td><td>95</td></tr><tr><td>17437</td><td>Reus</td><td>Germany</td><td>CAM</td><td>91.0</td><td>92.0</td><td>90</td></tr><tr><td>17469</td><td>Messi</td><td>Argentina</td><td>ST</td><td>98.0</td><td>93.0</td><td>96</td></tr><tr><td>17575</td><td>Ronaldo</td><td>Portugal</td><td>ST</td><td>98.0</td><td>99.0</td><td>99</td></tr><tr><td>17576</td><td>Messi</td><td>Argentina</td><td>CF</td><td>99.0</td><td>99.0</td><td>99</td></tr><tr><td>17577</td><td>Mbappé</td><td>France</td><td>RW</td><td>97.0</td><td>96.0</td><td>97</td></tr><tr><td>17578</td><td>De Bruyne</td><td>Belgium</td><td>CAM</td><td>96.0</td><td>96.0</td><td>97</td></tr><tr><td>17580</td><td>Modric</td><td>Croatia</td><td>CM</td><td>99.0</td><td>94.0</td><td>99</td></tr><tr><td>17613</td><td>Bale</td><td>Wales</td><td>RW</td><td>91.0</td><td>93.0</td><td>92</td></tr><tr><td>17618</td><td>Ibrahimovic</td><td>Sweden</td><td>ST</td><td>91.0</td><td>94.0</td><td>92</td></tr><tr><td>17620</td><td>Neymar Jr</td><td>Brazil</td><td>LW</td><td>99.0</td><td>95.0</td><td>97</td></tr><tr><td>17726</td><td>Reus</td><td>Germany</td><td>CAM</td><td>92.0</td><td>93.0</td><td>91</td></tr><tr><td>18977</td><td>Ronaldo</td><td>Portugal</td><td>ST</td><td>91.0</td><td>94.0</td><td>95</td></tr></tbody></table></div>

# %% [markdown]
# ## 2. Alterando o dataframe

# %% [markdown]
# Agora iremos utilizar o DataFrame _**pokemon_data**_. Essa base reúne informações sobre os Pokémons das diversas gerações da franquia, contendo atributos, classificações e estatísticas de batalha.
#
# Principais Colunas:
# - Name — nome do Pokémon
# - Type 1, Type 2 — tipos primário e secundário (ex: Fire, Water, Grass)
# - HP, Attack, Defense, Sp. Atk, Sp. Def, Speed — atributos de combate
# - Generation — geração à qual pertence
# - Legendary - Se e ou não um Pokémon lendário

# %%
pkmn = spark.table("workspace.default.pokemon_data")

display(pkmn.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr></thead><tbody><tr><td>1</td><td>Bulbasaur</td><td>Grass</td><td>Poison</td><td>318</td><td>45</td><td>49</td><td>49</td><td>65</td><td>65</td><td>45</td><td>1</td><td>false</td></tr><tr><td>2</td><td>Ivysaur</td><td>Grass</td><td>Poison</td><td>405</td><td>60</td><td>62</td><td>63</td><td>80</td><td>80</td><td>60</td><td>1</td><td>false</td></tr><tr><td>3</td><td>Venusaur</td><td>Grass</td><td>Poison</td><td>525</td><td>80</td><td>82</td><td>83</td><td>100</td><td>100</td><td>80</td><td>1</td><td>false</td></tr><tr><td>3</td><td>VenusaurMega Venusaur</td><td>Grass</td><td>Poison</td><td>625</td><td>80</td><td>100</td><td>123</td><td>122</td><td>120</td><td>80</td><td>1</td><td>false</td></tr><tr><td>4</td><td>Charmander</td><td>Fire</td><td>null</td><td>309</td><td>39</td><td>52</td><td>43</td><td>60</td><td>50</td><td>65</td><td>1</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# Até o momento apenas utilizamos os dados da forma que nos foram fornecidos, mas e se precisássemos criar alguma coluna que fosse a combinação das demais? Por exemplo, caso eu deseje criar uma coluna que corresponde à soma do ataque e velocidade dos Pokémons? Observe abaixo:

# %%
# Criando a coluna desejada
pkmn = pkmn.withColumn("Sum_Attack_Speed", F.col("Attack") + F.col("Speed"))
display(pkmn.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>Total</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th><th>Sum_Attack_Speed</th></tr></thead><tbody><tr><td>1</td><td>Bulbasaur</td><td>Grass</td><td>Poison</td><td>318</td><td>45</td><td>49</td><td>49</td><td>65</td><td>65</td><td>45</td><td>1</td><td>false</td><td>94</td></tr><tr><td>2</td><td>Ivysaur</td><td>Grass</td><td>Poison</td><td>405</td><td>60</td><td>62</td><td>63</td><td>80</td><td>80</td><td>60</td><td>1</td><td>false</td><td>122</td></tr><tr><td>3</td><td>Venusaur</td><td>Grass</td><td>Poison</td><td>525</td><td>80</td><td>82</td><td>83</td><td>100</td><td>100</td><td>80</td><td>1</td><td>false</td><td>162</td></tr><tr><td>3</td><td>VenusaurMega Venusaur</td><td>Grass</td><td>Poison</td><td>625</td><td>80</td><td>100</td><td>123</td><td>122</td><td>120</td><td>80</td><td>1</td><td>false</td><td>180</td></tr><tr><td>4</td><td>Charmander</td><td>Fire</td><td>null</td><td>309</td><td>39</td><td>52</td><td>43</td><td>60</td><td>50</td><td>65</td><td>1</td><td>false</td><td>117</td></tr></tbody></table></div>

# %% [markdown]
# Observe como foi fácil! Apenas utilizamos o operador de soma com as duas colunas necessárias. Você pode fazer isso com outras operações também, basta utilizar ```-```, ```/``` ou ```*```. Além disso, você pode combinar quantas colunas quiser!
#
# Mas e se precisarmos alterar apenas algumas linhas do nosso DataFrame?
#
# Por exemplo, suponha que você percebeu que seus dados estão errados, e todos os Pokémons com velocidade acima de 100 deveriam estar marcados como Type_1 = 'Fire', podemos seguir o procedimento abaixo:

# %%
# Observe os valores unicos da coluna Type_1 para os Pokémons com mais de 100 de velocidade
pkmn.filter(pkmn["Speed"] > 100).select("Type 1").distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Type 1</th></tr></thead><tbody><tr><td>Grass</td></tr><tr><td>Fire</td></tr><tr><td>Water</td></tr><tr><td>Bug</td></tr><tr><td>Normal</td></tr><tr><td>Poison</td></tr><tr><td>Electric</td></tr><tr><td>Ground</td></tr><tr><td>Fighting</td></tr><tr><td>Psychic</td></tr><tr><td>Rock</td></tr><tr><td>Ghost</td></tr><tr><td>Ice</td></tr><tr><td>Dragon</td></tr><tr><td>Dark</td></tr><tr><td>Steel</td></tr><tr><td>Flying</td></tr></tbody></table></div>

# %%
# Vamos alterar os casos onde Speed é superior a 100 para Fire
pkmn = pkmn.withColumn(
    "Type 1",
    F.when(pkmn["Speed"] > 100, "Fire").otherwise(pkmn["Type 1"])
)

# %%
# Observe como os valores mudaram
pkmn.filter(pkmn["Speed"] > 100).select("Type 1").distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Type 1</th></tr></thead><tbody><tr><td>Fire</td></tr></tbody></table></div>

# %% [markdown]
# Relendo o arquivo para desconsiderar os tratamentos de exemplos que fizemos acima

# %%
pkmn = spark.table("workspace.default.pokemon_data")

# Renomeando as colunas
pkmn = (
    pkmn
    .withColumnRenamed("Type 1", "Type_1")
    .withColumnRenamed("Type 2", "Type_2")
    .withColumnRenamed("Sp. Atk", "Sp_Atk")
    .withColumnRenamed("Sp. Def", "Sp_Def")
)

# %% [markdown]
# ## 3. Operações em grupo
#
# Com PySpark nós podemos aplicar operações em grupos usando o método *.groupby()*. Ele é muito útil por ser uma forma bem simples de extrair informação de dados agregados. Para utilizá-lo, passamos as colunas nas quais queremos agrupar os dados e a operação que queremos fazer. Para exemplificar, vamos ver quantos Pokémons lendários cada geração tem:

# %%
pkmn_soma = (pkmn
            .groupBy("Generation") # Campo que sera agrupado
            .agg(
                F.sum(F.col("Legendary").cast("int")) # Converte a coluna "Legendary" em inteiro e faz a soma
                .alias("Qtd_Legendary") # Nomeando a coluna que receberá o resultado da soma
                )
            )
pkmn_soma.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Generation</th><th>Qtd_Legendary</th></tr></thead><tbody><tr><td>1</td><td>6</td></tr><tr><td>2</td><td>5</td></tr><tr><td>3</td><td>18</td></tr><tr><td>4</td><td>13</td></tr><tr><td>5</td><td>15</td></tr><tr><td>6</td><td>8</td></tr></tbody></table></div>

# %% [markdown]
# Podemos obter um relatório da média de diversas colunas para cada tipo de Pokémon:

# %%
pkmn_media = (pkmn
                .groupBy("Type_1")
                .agg(
                    F.mean("HP").alias("HP_medio"),
                    F.mean("Attack").alias("Attack_medio"),
                    F.mean("Defense").alias("Defense_medio")
                    )
                )
pkmn_media.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Type_1</th><th>HP_medio</th><th>Attack_medio</th><th>Defense_medio</th></tr></thead><tbody><tr><td>Grass</td><td>67.27142857142857</td><td>73.21428571428571</td><td>70.8</td></tr><tr><td>Fire</td><td>69.90384615384616</td><td>84.76923076923077</td><td>67.76923076923077</td></tr><tr><td>Water</td><td>72.0625</td><td>74.15178571428571</td><td>72.94642857142857</td></tr><tr><td>Bug</td><td>56.88405797101449</td><td>70.97101449275362</td><td>70.72463768115942</td></tr><tr><td>Normal</td><td>77.27551020408163</td><td>73.46938775510205</td><td>59.8469387755102</td></tr><tr><td>Poison</td><td>67.25</td><td>74.67857142857143</td><td>68.82142857142857</td></tr><tr><td>Electric</td><td>59.79545454545455</td><td>69.0909090909091</td><td>66.29545454545455</td></tr><tr><td>Ground</td><td>73.78125</td><td>95.75</td><td>84.84375</td></tr><tr><td>Fairy</td><td>74.11764705882354</td><td>61.529411764705884</td><td>65.70588235294117</td></tr><tr><td>Fighting</td><td>69.85185185185185</td><td>96.77777777777777</td><td>65.92592592592592</td></tr><tr><td>Psychic</td><td>70.63157894736842</td><td>71.45614035087719</td><td>67.6842105263158</td></tr><tr><td>Rock</td><td>65.36363636363636</td><td>92.86363636363636</td><td>100.79545454545455</td></tr><tr><td>Ghost</td><td>64.4375</td><td>73.78125</td><td>81.1875</td></tr><tr><td>Ice</td><td>72.0</td><td>72.75</td><td>71.41666666666667</td></tr><tr><td>Dragon</td><td>83.3125</td><td>112.125</td><td>86.375</td></tr><tr><td>Dark</td><td>66.80645161290323</td><td>88.38709677419355</td><td>70.2258064516129</td></tr><tr><td>Steel</td><td>65.22222222222223</td><td>92.70370370370371</td><td>126.37037037037037</td></tr><tr><td>Flying</td><td>70.75</td><td>78.75</td><td>66.25</td></tr></tbody></table></div>

# %% [markdown]
# ###  Exercício 2
# Use o método *.groupby()* para descobrir qual país tem o melhor *overall* médio. Crie a coluna 'avg_overall'
#
# Seu df country_avg_overall deve conter as seguintes colunas:
# - `nationality`
# - `overall`
# - `avg_overall`

# %%
country_avg_overall = (
    fut_players
    .groupBy("nationality")
    .agg(F.avg("overall").alias("avg_overall"))
)

# Retornar a nacionalidade com maior overall médio e o overall médio do brasil
melhor = (
    country_avg_overall
    .orderBy(F.col("avg_overall").desc())
    .limit(1)
    .collect()[0]
)

brasil = (
    country_avg_overall
    .filter(F.col("nationality") == "Brazil")
    .collect()[0]
)

display({
    "Melhor overall médio": f"{melhor['nationality']}: {melhor['avg_overall']:.2f}",
    "Overall médio do Brasil": round(brasil['avg_overall'], 2)
})
# Out:
# {'Melhor overall médio': 'Dominican Republic: 79.00',
#  'Overall médio do Brasil': 75.22}

# %% [markdown]
# Agora nós já cobrimos toda a parte básica do Spark! Vamos praticar essa última parte!
#
# ### Exercício 2.1
# Crie um racional que retorne a classificação para o jogador de acordo com as instruções abaixo, então aplique isso para o dataframe fut_players.
#
# *Observação:* considere os limites dentro do intervalo de classificação.
# exemplo
#
# -50 contém todos os valores menores que 50 e o valor 50 incluso;
#
#
# 51-60 contém todos os valores entre 51 e 60 com os limites [51,60] inclusos no grupo;
#
#
# e assim por diante ...

# %%
"""
    Através do overall do jogador retorne a classificação conforme a seguir:
    Overall -> classification
    -50     -> "Amador"
    51-60   -> "Ruim"
    61-70   -> "Ok"
    71-80   -> "Bom"
    81-90   -> "Ótimo"
    91+     -> "Lenda"
    
    I: int overall
    O: string
"""
# Dica utilize as clasulas when e otherwise
fut_players = (fut_players
               .select('player_id', 'overall')
               .withColumn('classification', 
                           F.when(F.col('overall') <= 50, 'Amador')  
                            .when(F.col('overall') <= 60, 'Ruim')  
                            .when(F.col('overall') <= 70, 'Ok')
                            .when(F.col('overall') <= 80, 'Bom')
                            .when(F.col('overall') <= 90, 'Ótimo') 
                            .otherwise('Lenda')                   
               )
)

# Contar quantos jogadores há em cada classificação
fut_players.groupBy("classification").count().orderBy("count", ascending=False).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>classification</th><th>count</th></tr></thead><tbody><tr><td>Ok</td><td>9500</td></tr><tr><td>Bom</td><td>4785</td></tr><tr><td>Ruim</td><td>2788</td></tr><tr><td>Ótimo</td><td>1482</td></tr><tr><td>Lenda</td><td>141</td></tr><tr><td>Amador</td><td>135</td></tr></tbody></table></div>

# %% [markdown]
# ## Desafio — Montando o Time dos Sonhos do 🇧🇷
#
# Ainda utilizando a base **`fut_players_data`**, imagine que você é um grande fã do jogo *FIFA*, e deseja montar o **Time dos Sonhos (Dream Team)** do **Brasil**, selecionando os **melhores jogadores por posição**, ou seja, aqueles com o **maior overall** dentro de cada grupo de posição.
#
# Para isso, adote a **formação tática 4-4-2**, composta por:
#
# - **1 Goleiro (GK)**
# - **4 Defensores (Defesa)**
# - **4 Meio-campistas (Meio)**
# - **2 Atacantes (Ataque)**
#
# ### Objetivo
# Criar um *DataFrame* com **11 linhas**, representando o **melhor jogador de cada posição dentro da formação 4-4-2**, com as seguintes colunas:
#
# - `nationality` — nacionalidade do jogador
# - `position_group` — posição agrupada (Goleiro, Defesa, Meio, Ataque)
# - `player_name` — nome do jogador
# - `overall` — nota geral (overall)
#
# ---
#
# ### Agrupamento de posições
# Para facilitar a análise, agrupe as posições originais da base conforme a tabela abaixo:
#
# | **position_group** | **Posições incluídas (`position`)** | **Descrição** |
# |:--------------------|:------------------------------------|:---------------|
# | **Goleiro** | `GK` | Jogadores que atuam exclusivamente no gol. |
# | **Defesa** | `CB`, `LB`, `RB`, `LWB`, `RWB` | Zagueiros e laterais (defensores). |
# | **Meio** | `CM`, `CDM`, `CAM`, `LM`, `RM` | Meio-campistas centrais, volantes e meias ofensivos/laterais. |
# | **Ataque** | `ST`, `CF`, `LW`, `RW`, `LF`, `RF` | Atacantes e pontas. |
# | **Outros** | *(demais posições não classificadas)* | Jogadores fora do esquema tático principal (ex: cartas especiais). |
#
# ---
#
# ### 🏁 Entrega esperada
# Seu *DataFrame final* deve retornar **11 jogadores**, representando o **Time dos Sonhos do Brasil (formação 4-4-2)**, conforme os critérios acima.

# %%
fut_players = spark.table("workspace.default.fut_players_data")

df_brasil = fut_players.filter(F.col("nationality") == "Brazil")
df_brasil = df_brasil.withColumn(
    "position_group",
    F.when(F.col("position") == "GK", "Goleiro")
     .when(F.col("position").isin("CB", "LB", "RB", "LWB", "RWB"), "Defesa")
     .when(F.col("position").isin("CM", "CDM", "CAM", "LM", "RM"), "Meio")
     .when(F.col("position").isin("ST", "CF", "LW", "RW", "LF", "RF"), "Ataque")
     .otherwise("Outros")
)

df_valid = df_brasil.filter(F.col("position_group").isin("Goleiro", "Defesa", "Meio", "Ataque"))

limits = {
    "Goleiro": 1,
    "Defesa": 4,
    "Meio": 4,
    "Ataque": 2
}

#ranking por overall
window = Window.partitionBy("position_group").orderBy(F.col("overall").desc())

df_ranked = df_valid.withColumn("rank", F.row_number().over(window))

df_dream_team = df_ranked.filter(
    F.expr(
        "case position_group "
        "when 'Goleiro' then rank <= 1 "
        "when 'Defesa' then rank <= 4 "
        "when 'Meio' then rank <= 4 "
        "when 'Ataque' then rank <= 2 "
        "end"
    )
)

df_dream_team = df_dream_team.withColumn( #para printar na ordem tática goleiro até atacante
    "tactical_order",
    F.when(F.col("position_group") == "Goleiro", 1)
     .when(F.col("position_group") == "Defesa", 2)
     .when(F.col("position_group") == "Meio", 3)
     .when(F.col("position_group") == "Ataque", 4)
)

df_final = (
    df_dream_team
    .select("nationality", "position_group", "player_name", "overall")
    .orderBy("tactical_order", F.col("overall").desc()) # ordem tática garantida, coloquei por overall em cada posição apenas para facilitar entendimento.
)

display(df_final)

#Atenção: Como a base de dados é menor, decidi utilizar a função Window, porém me recordo, como dito em aula, que pode ser que em um cenário real isso não seja viável essa utilização, por isso, uma alternativa seria fazer um diferentes df para cada posição e depois fazer um union, essa alternativa seria menos custosa em cenários onde a quantidade de dados é grande. Optei pelo window, para entender melhor como funciona essa função. Uma vez que já tivemos contato com filter e union em outras etapas dessa atividade.
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nationality</th><th>position_group</th><th>player_name</th><th>overall</th></tr></thead><tbody><tr><td>Brazil</td><td>Goleiro</td><td>Ederson</td><td>87</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Marcelo</td><td>94</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Carlos</td><td>91</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Thiago Silva</td><td>90</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Dani Alves</td><td>90</td></tr><tr><td>Brazil</td><td>Meio</td><td>Pelé</td><td>98</td></tr><tr><td>Brazil</td><td>Meio</td><td>Neymar Jr</td><td>94</td></tr><tr><td>Brazil</td><td>Meio</td><td>Sócrates</td><td>91</td></tr><tr><td>Brazil</td><td>Meio</td><td>Ronaldinho</td><td>91</td></tr><tr><td>Brazil</td><td>Ataque</td><td>Neymar Jr</td><td>97</td></tr><tr><td>Brazil</td><td>Ataque</td><td>Ronaldo</td><td>96</td></tr></tbody></table></div>

# %% [markdown]
# ### Desafio Bônus
#
# Você deve ter notado que **Neymar** aparece tanto entre os melhores jogadores de **ataque** quanto do **meio-campo**.
# Isso acontece porque o dataset contém **múltiplas versões do mesmo jogador**, inclusive atuando em **outras posições**, o que é típico dos modos do *FIFA/Ultimate Team*.
#
# O seu desafio agora é **refazer o exercício anterior**, garantindo que **cada jogador apareça apenas uma vez** no *DataFrame final*.
#
# - Caso o jogador possua mais de uma versão (carta), **considere apenas aquela com o maior valor de `overall`**.
# - Em seguida, **reaplique a lógica da formação 4-4-2**, selecionando os melhores por grupo de posição.
#
# ---
#
# ### 🏁 Entrega Esperada
# Seu *DataFrame final* deve retornar **11 jogadores únicos**, representando o **Dream Team do Brasil** na **formação tática 4-4-2**, **sem repetição de atletas**, conforme os critérios estabelecidos acima.

# %%
#Muitas coisas estão sendo já carregadas na célula do desafio acima, como por exemplo a coluna position_group, bem como toda lógica de 
#agrupamento por posição, com isso, para n repetir código resolvi apenas colocar as alterações aqui, mas saiba que estou utilizando dados
#da célula acima, isto é, para essa funcionar devemos primeiro rodar a célula de código anterior.

window_player = Window.partitionBy("player_name").orderBy(F.col("overall").desc()) # rank do pelo nome do jogador para pegar a melhor versão do jogador.

df_best_version = (
    df_valid
    .withColumn("best_rank", F.row_number().over(window_player))
    .filter(F.col("best_rank") == 1)
    .drop("best_rank")
)

df_ranked = df_best_version.withColumn("rank", F.row_number().over(window)) #chama o window criado anteriormente

df_dream_team = df_ranked.filter(
    F.expr(
        "case position_group "
        "when 'Goleiro' then rank <= 1 "
        "when 'Defesa' then rank <= 4 "
        "when 'Meio' then rank <= 4 "
        "when 'Ataque' then rank <= 2 "
        "end"
    )
)

df_dream_team = df_dream_team.withColumn(
    "tactical_order",
    F.when(F.col("position_group") == "Goleiro", 1)
     .when(F.col("position_group") == "Defesa", 2)
     .when(F.col("position_group") == "Meio", 3)
     .when(F.col("position_group") == "Ataque", 4)
)

df_final = (
    df_dream_team
    .select("nationality", "position_group", "player_name", "overall")
    .orderBy("tactical_order", F.col("overall").desc())
)

display(df_final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nationality</th><th>position_group</th><th>player_name</th><th>overall</th></tr></thead><tbody><tr><td>Brazil</td><td>Goleiro</td><td>Ederson</td><td>87</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Marcelo</td><td>94</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Carlos</td><td>91</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Thiago Silva</td><td>90</td></tr><tr><td>Brazil</td><td>Defesa</td><td>Dani Alves</td><td>90</td></tr><tr><td>Brazil</td><td>Meio</td><td>Pelé</td><td>98</td></tr><tr><td>Brazil</td><td>Meio</td><td>Sócrates</td><td>91</td></tr><tr><td>Brazil</td><td>Meio</td><td>Casemiro</td><td>90</td></tr><tr><td>Brazil</td><td>Meio</td><td>Arthur</td><td>90</td></tr><tr><td>Brazil</td><td>Ataque</td><td>Neymar Jr</td><td>97</td></tr><tr><td>Brazil</td><td>Ataque</td><td>Ronaldo</td><td>96</td></tr></tbody></table></div>

# %% [markdown]
# # Declaração de Inexistência de Plágio:
#
# 1. Eu sei que plágio é utilizar o trabalho de outra pessoa e apresentar como meu.
# 2. Eu sei que plágio é errado e declaro que este notebook foi feito por mim.
# 3. Tenho consciência de que a utilização do trabalho de terceiros é antiético e está sujeito a medidas administrativas.
# 4. Declaro também que não compartilhei e não compartilharei meu trabalho com o intuito de que seja copiado e submetido por outra pessoa.

# %% [markdown]
# # Fim da aula!
#
# Obrigado por participar do curso, você acaba de finalizar o Módulo de Pyspark. Neste momento você já deve ser capaz de manipular seus dados no Spark, utilizando as bibliotecas que acabamos de aprender!
#
# Lembre-se que sempre que surgir alguma dúvida, você pode olhar a documentação do [PySpark](https://spark.apache.org/docs/latest/api/python/reference).
